# %%
options(warn = -1)
suppressPackageStartupMessages(library(tidyverse))

# %%
args <- commandArgs(trailingOnly = TRUE)

raw_count_file <- args[1]
linked_count_file <- args[2]
umi_cutoff <- as.numeric(args[3])
output_file <- args[4]
# raw_count_file <- "../data/barcode_umi_and_read_counts/pn_219p19_219p27.csv"
# linked_count_file <- "../data/subpool_barcode_counts/219p27.csv"
# umi_cutoff <- 20
# output_file <- "../data/library_statistics/219p27.csv"

# %% [markdown]
# ### Load sample annotations

# %%
sample_annotations <- read_csv("../annotations/sample_annotations.csv", show_col_types = F)

sample_annotations
# Out:
#    sample_number owner sample_name                    library_type
# 1   1            pn    ptc_bc1_total                  mrna
# 2   2            pn    ntc_bc1_total                  mrna
# 3   3            pn    eyfpwt_bc1_total               mrna
# 4   4            pn    eyfpdeopt_bc1_total            mrna
# 5  13            pn    ptc_bc2_total                  mrna
# 6  14            pn    eyfpdeopt_bc2_total            mrna
# 7  15            pn    ntc_bc1_i2_retained            mrna
# 8  16            pn    ptc_bc1_i2_retained            mrna
# 9  17            pn    ntc_bc1_cpa                    mrna
# 10 18            pn    eyfpwt_bc1_cpa                 mrna
# 11 19            pn    eyfpdeopt_bc2_cpa              mrna
# 12 20            pn    ptc_monosome_bc1_total         mrna
# 13 21            pn    ptc_polysome_bc1_total         mrna
# 14 22            pn    eyfpdeopt_monosome_bc1_total   mrna
# 15 23            pn    eyfpdeopt_polysome_bc1_total   mrna
# 16 24            pn    ntc_e1i1junc_bc1_i1_retained   mrna
# 17 25            pn    ntc_i1e2junc_bc1_i1_retained   mrna
# 18 26            pn    ntc_i2e3junc_bc1_i2_retained   mrna
# 19 27            pn    ntc_splicing_bc1_e2_skipped    mrna
# 20 28            pn    ptc_sghri_bc1_total            mrna
# 21 29            pn    ptc_sgpkr_bc1_total            mrna
# 22 30            pn    ptc_sgperk_bc1_total           mrna
# 23 31            pn    ptc_sggcn2_bc1_total           mrna
# 24 32            pn    ptc_sgcontrol_bc1_total        mrna
# 25 33            pn    ptc_isrib_2_bc1_total          mrna
# 26 34            pn    ptc_dmso_2_bc1_total           mrna
# 27 35            pn    ptc_isrib_1_bc1_total          mrna
# 28 36            pn    ptc_gcn2i_1_bc1_total          mrna
# 29 37            pn    ptc_perki_1_bc1_total          mrna
# 30 38            pn    ptc_dmso_1_bc1_total           mrna
# ⋮  ⋮             ⋮     ⋮                              ⋮
# 67  83           pn    ntc_day7_pladb_bc1_i1_retained mrna
# 68  84           pn    ntc_day7_pladb_bc1_i2_retained mrna
# 69  85           pn    ntc_day7_pladb_bc1_e2_skipped  mrna
# 70  86           pn    ntc_day7_mg132_bc1_i1_retained mrna
# 71  87           pn    ntc_day7_mg132_bc1_i2_retained mrna
# 72  88           pn    ntc_day7_mg132_bc1_e2_skipped  mrna
# 73  89           pn    ntc_day1_bc1_i2_retained       mrna
# 74  90           pn    ntc_day3_bc1_i2_retained       mrna
# 75  91           pn    ntc_day5_bc1_i2_retained       mrna
# 76  92           pn    pig3_day7_dmso_bc1_e2_retained mrna
# 77  93           pn    ntc_day1_bc1_grna              grna
# 78  94           pn    ntc_day5_bc1_grna              grna
# 79  95           pn    ntc_day13_bc1_grna             grna
# 80  96           pn    ntc_day21_bc1_grna             grna
# 81  97           pn    ntc_day1_bc1_i1_retained       mrna
# 82  98           pn    ntc_day1_bc1_e2_skipped        mrna
# 83  99           pn    ntc_day3_bc1_i1_retained       mrna
# 84 100           pn    ntc_day3_bc1_e2_skipped        mrna
# 85 101           pn    ntc_day5_bc1_i1_retained       mrna
# 86 102           pn    ntc_day5_bc1_e2_skipped        mrna
# 87 103           pn    ptc_polysome_bc1_total         mrna
# 88 104           pn    ptc_polysome_bc1_mono          mrna
# 89 105           pn    ptc_polysome_bc1_light         mrna
# 90 106           pn    ptc_polysome_bc1_heavy         mrna
# 91 107           pn    ntc_polysome_bc1_total         mrna
# 92 108           pn    ntc_polysome_bc1_mono          mrna
# 93 109           pn    ntc_polysome_bc1_light         mrna
# 94 110           pn    ntc_polysome_bc1_heavy         mrna
# 95 111           pn    ntc_bc2_total                  mrna
# 96 112           pn    eyfpwt_bc2_total               mrna
#    plasmid_snapgene_map amplicon_snapgene_map illumina_sample_id
# 1  pHPHS949             lPNHS23               pn_179p1_179p2_179p3_179p4
# 2  pHPHS950             lPNHS23               pn_179p1_179p2_179p3_179p4
# 3  pHPHS951             lPNHS23               pn_179p1_179p2_179p3_179p4
# 4  pHPHS952             lPNHS23               pn_179p1_179p2_179p3_179p4
# 5  pHPHS949             lPNHS24               pn_179p7_179p8
# 6  pHPHS952             lPNHS24               pn_179p7_179p8
# 7  pHPHS950             lPNHS26               pn_188p1
# 8  pHPHS949             lPNHS26               pn_188p2
# 9  pHPHS950             lPNHS27               pn_191p23
# 10 pHPHS951             lPNHS27               pn_191p23
# 11 pHPHS952             lPNHS28               pn_191p4
# 12 pHPHS949             lPNHS23               pn_184p13
# 13 pHPHS949             lPNHS23               pn_184p24
# 14 pHPHS952             lPNHS23               pn_184p13
# 15 pHPHS952             lPNHS23               pn_184p24
# 16 pHPHS950             lPNHS29               pn_188p17
# 17 pHPHS950             lPNHS29               pn_188p18
# 18 pHPHS950             lPNHS29               pn_188p19
# 19 pHPHS950             lPNHS29               pn_188p20
# 20 pHPHS949             lPNHS23               pn_207p1_208p1
# 21 pHPHS949             lPNHS23               pn_207p2_208p2
# 22 pHPHS949             lPNHS23               pn_207p3_208p3
# 23 pHPHS949             lPNHS23               pn_207p4_208p4
# 24 pHPHS949             lPNHS23               pn_207p5_208p5
# 25 pHPHS949             lPNHS23               pn_207p7_208p7
# 26 pHPHS949             lPNHS23               pn_207p8_208p8
# 27 pHPHS949             lPNHS23               pn_207p9_208p9
# 28 pHPHS949             lPNHS23               pn_207p10_208p10
# 29 pHPHS949             lPNHS23               pn_207p11_208p11
# 30 pHPHS949             lPNHS23               pn_207p12_208p12
# ⋮  ⋮                    ⋮                     ⋮
# 67 pAS244               lPNHS23               pn_219p42
# 68 pAS244               lPNHS23               pn_219p43
# 69 pAS244               lPNHS23               pn_219p44
# 70 pAS244               lPNHS23               pn_219p45
# 71 pAS244               lPNHS23               pn_219p46
# 72 pAS244               lPNHS23               pn_219p47
# 73 pAS244               lPNHS23               pn_219p48
# 74 pAS244               lPNHS23               pn_219p49
# 75 pAS244               lPNHS23               pn_219p50
# 76 pAS246               lPNHS23               pn_219p51
# 77 pAS244               lPNHS21               pn_219p138
# 78 pAS244               lPNHS21               pn_219p139
# 79 pAS244               lPNHS21               pn_219p140
# 80 pAS244               lPNHS21               pn_219p141
# 81 pAS244               lPNHS23               pn_219p152
# 82 pAS244               lPNHS23               pn_219p153
# 83 pAS244               lPNHS23               pn_219p154
# 84 pAS244               lPNHS23               pn_219p155
# 85 pAS244               lPNHS23               pn_219p156
# 86 pAS244               lPNHS23               pn_219p257
# 87 pAS243               lPNHS23               pn_228p1_228p5
# 88 pAS243               lPNHS23               pn_228p2_228p6
# 89 pAS243               lPNHS23               pn_228p3_228p7
# 90 pAS243               lPNHS23               pn_228p4_228p8
# 91 pAS244               lPNHS23               pn_228p1_228p5
# 92 pAS244               lPNHS23               pn_228p2_228p6
# 93 pAS244               lPNHS23               pn_228p3_228p7
# 94 pAS244               lPNHS23               pn_228p4_228p8
# 95 pHPHS950             lPNHS24               pn_228p9_228p10
# 96 pHPHS951             lPNHS24               pn_228p9_228p10
#    sample_id barcode1_read barcode1_start ⋯ umi_read umi_start umi_length
# 1  179p1     1             1              ⋯ 2        1         7
# 2  179p2     1             1              ⋯ 2        1         7
# 3  179p3     1             1              ⋯ 2        1         7
# 4  179p4     1             1              ⋯ 2        1         7
# 5  179p7     1             1              ⋯ 2        1         7
# 6  179p8     1             1              ⋯ 2        1         7
# 7  188p1     1             1              ⋯ 2        1         7
# 8  188p2     1             1              ⋯ 2        1         7
# 9  191p2     1             1              ⋯ 2        1         7
# 10 191p3     1             1              ⋯ 2        1         7
# 11 191p4     1             4              ⋯ 2        1         7
# 12 184p1     1             1              ⋯ 2        1         7
# 13 184p2     1             1              ⋯ 2        1         7
# 14 184p3     1             1              ⋯ 2        1         7
# 15 184p4     1             1              ⋯ 2        1         7
# 16 188p17    1             1              ⋯ 2        1         7
# 17 188p18    1             1              ⋯ 2        1         7
# 18 188p19    1             1              ⋯ 2        1         7
# 19 188p20    1             1              ⋯ 2        1         7
# 20 207p1     1             1              ⋯ 2        1         7
# 21 207p2     1             1              ⋯ 2        1         7
# 22 207p3     1             1              ⋯ 2        1         7
# 23 207p4     1             1              ⋯ 2        1         7
# 24 207p5     1             1              ⋯ 2        1         7
# 25 207p7     1             1              ⋯ 2        1         7
# 26 207p8     1             1              ⋯ 2        1         7
# 27 207p9     1             1              ⋯ 2        1         7
# 28 207p10    1             1              ⋯ 2        1         7
# 29 207p11    1             1              ⋯ 2        1         7
# 30 207p12    1             1              ⋯ 2        1         7
# ⋮  ⋮         ⋮             ⋮              ⋱ ⋮        ⋮         ⋮
# 67 219p42    1             1              ⋯ 2        1         7
# 68 219p43    1             1              ⋯ 2        1         7
# 69 219p44    1             1              ⋯ 2        1         7
# 70 219p45    1             1              ⋯ 2        1         7
# 71 219p46    1             1              ⋯ 2        1         7
# 72 219p47    1             1              ⋯ 2        1         7
# 73 219p48    1             1              ⋯ 2        1         7
# 74 219p49    1             1              ⋯ 2        1         7
# 75 219p50    1             1              ⋯ 2        1         7
# 76 219p51    1             1              ⋯ 2        1         7
# 77 219p138   1             1              ⋯ 2        1         7
# 78 219p139   1             1              ⋯ 2        1         7
# 79 219p140   1             1              ⋯ 2        1         7
# 80 219p141   1             1              ⋯ 2        1         7
# 81 219p152   1             1              ⋯ 2        1         7
# 82 219p153   1             1              ⋯ 2        1         7
# 83 219p154   1             1              ⋯ 2        1         7
# 84 219p155   1             1              ⋯ 2        1         7
# 85 219p156   1             1              ⋯ 2        1         7
# 86 219p257   1             1              ⋯ 2        1         7
# 87 228p1     1             1              ⋯ 2        1         7
# 88 228p2     1             1              ⋯ 2        1         7
# 89 228p3     1             1              ⋯ 2        1         7
# 90 228p4     1             1              ⋯ 2        1         7
# 91 228p5     1             1              ⋯ 2        1         7
# 92 228p6     1             1              ⋯ 2        1         7
# 93 228p7     1             1              ⋯ 2        1         7
# 94 228p8     1             1              ⋯ 2        1         7
# 95 228p9     1             1              ⋯ 2        1         7
# 96 228p10    1             1              ⋯ 2        1         7
#    linkage_ref linkage_ref_barcode_number run_id
# 1  182p1       1                          230104_VH01189_46_AACH77JM5
# 2  182p1       1                          230104_VH01189_46_AACH77JM5
# 3  182p1       1                          230104_VH01189_46_AACH77JM5
# 4  182p1       1                          230104_VH01189_46_AACH77JM5
# 5  182p1       2                          230202_VH01189_62_AACJKHVM5
# 6  182p1       2                          230202_VH01189_62_AACJKHVM5
# 7  182p1       1                          230202_VH01189_62_AACJKHVM5
# 8  182p1       1                          230302_VH00319_324_AACKHCLM5
# 9  182p1       1                          230302_VH00319_324_AACKHCLM5
# 10 182p1       1                          230302_VH00319_324_AACKHCLM5
# 11 182p1       2                          230302_VH00319_324_AACKHCLM5
# 12 182p1       1                          230302_VH00319_324_AACKHCLM5
# 13 182p1       1                          230302_VH00319_324_AACKHCLM5
# 14 182p1       1                          230302_VH00319_324_AACKHCLM5
# 15 182p1       1                          230302_VH00319_324_AACKHCLM5
# 16 182p1       1                          230602_VH00699_321_AACTH25M5
# 17 182p1       1                          230602_VH00699_321_AACTH25M5
# 18 182p1       1                          230602_VH00699_321_AACTH25M5
# 19 182p1       1                          230602_VH00699_321_AACTH25M5
# 20 182p1       1                          230615_VH01189_126_AACVCG5M5-1
# 21 182p1       1                          230615_VH01189_126_AACVCG5M5-1
# 22 182p1       1                          230615_VH01189_126_AACVCG5M5-1
# 23 182p1       1                          230615_VH01189_126_AACVCG5M5-1
# 24 182p1       1                          230615_VH01189_126_AACVCG5M5-1
# 25 182p1       1                          230615_VH01189_126_AACVCG5M5-1
# 26 182p1       1                          230615_VH01189_126_AACVCG5M5-1
# 27 182p1       1                          230615_VH01189_126_AACVCG5M5-1
# 28 182p1       1                          230615_VH01189_126_AACVCG5M5-1
# 29 182p1       1                          230615_VH01189_126_AACVCG5M5-1
# 30 182p1       1                          230615_VH01189_126_AACVCG5M5-1
# ⋮  ⋮           ⋮                          ⋮
# 67 182p1       1                          231010_VH01189_173_AAC7VWVHV
# 68 182p1       1                          231010_VH01189_173_AAC7VWVHV
# 69 182p1       1                          231010_VH01189_173_AAC7VWVHV
# 70 182p1       1                          231010_VH01189_173_AAC7VWVHV
# 71 182p1       1                          231010_VH01189_173_AAC7VWVHV
# 72 182p1       1                          231010_VH01189_173_AAC7VWVHV
# 73 182p1       1                          231010_VH01189_173_AAC7VWVHV
# 74 182p1       1                          231010_VH01189_173_AAC7VWVHV
# 75 182p1       1                          231010_VH01189_173_AAC7VWVHV
# 76 182p1       1                          231010_VH01189_173_AAC7VWVHV
# 77 182p1       1                          231010_VH01189_173_AAC7VWVHV
# 78 182p1       1                          231010_VH01189_173_AAC7VWVHV
# 79 182p1       1                          231010_VH01189_173_AAC7VWVHV
# 80 182p1       1                          231010_VH01189_173_AAC7VWVHV
# 81 182p1       1                          231214_VH00319_439_AACF35YHV
# 82 182p1       1                          231214_VH00319_439_AACF35YHV
# 83 182p1       1                          231214_VH00319_439_AACF35YHV
# 84 182p1       1                          231214_VH00319_439_AACF35YHV
# 85 182p1       1                          231214_VH00319_439_AACF35YHV
# 86 182p1       1                          231214_VH00319_439_AACF35YHV
# 87 182p1       1                          240123_VH00319_450_AAFGTF2M5
# 88 182p1       1                          240123_VH00319_450_AAFGTF2M5
# 89 182p1       1                          240123_VH00319_450_AAFGTF2M5
# 90 182p1       1                          240123_VH00319_450_AAFGTF2M5
# 91 182p1       1                          240123_VH00319_450_AAFGTF2M5
# 92 182p1       1                          240123_VH00319_450_AAFGTF2M5
# 93 182p1       1                          240123_VH00319_450_AAFGTF2M5
# 94 182p1       1                          240123_VH00319_450_AAFGTF2M5
# 95 182p1       2                          240123_VH00319_450_AAFGTF2M5
# 96 182p1       2                          240123_VH00319_450_AAFGTF2M5
#    read1_length read2_length read3_length subpool_barcode
# 1  60           7            60           CGTGAT
# 2  60           7            60           CACTGT
# 3  60           7            60           ATTGGC
# 4  60           7            60           GATCTC
# 5  60           7            60           CGTGAT
# 6  60           7            60           GATCTC
# 7  60           7            60           CACTGT
# 8  30           7            80           ATCACG
# 9  30           7            80           ACAGTG
# 10 30           7            80           GCCAAT
# 11 30           7            80           GAGATC
# 12 30           7            80           ATCACG
# 13 30           7            80           ATCACG
# 14 30           7            80           GAGATC
# 15 30           7            80           GAGATC
# 16 30           7            70           ACAGTG
# 17 30           7            70           ACAGTG
# 18 30           7            70           ACAGTG
# 19 30           7            70           ACAGTG
# 20 50           7            50           ATCACG
# 21 50           7            50           ATCACG
# 22 50           7            50           ATCACG
# 23 50           7            50           ATCACG
# 24 50           7            50           ATCACG
# 25 50           7            50           ATCACG
# 26 50           7            50           ATCACG
# 27 50           7            50           ATCACG
# 28 50           7            50           ATCACG
# 29 50           7            50           ATCACG
# 30 50           7            50           ATCACG
# ⋮  ⋮            ⋮            ⋮            ⋮
# 67 26           7            26           ACAGTG
# 68 26           7            26           ACAGTG
# 69 26           7            26           ACAGTG
# 70 26           7            26           ACAGTG
# 71 26           7            26           ACAGTG
# 72 26           7            26           ACAGTG
# 73 26           7            26           ACAGTG
# 74 26           7            26           ACAGTG
# 75 26           7            26           ACAGTG
# 76 26           7            26           ACAGTG
# 77 26           7            26           ACAGTG
# 78 26           7            26           ACAGTG
# 79 26           7            26           ACAGTG
# 80 26           7            26           ACAGTG
# 81 52           7             0           CACTGT
# 82 52           7             0           CACTGT
# 83 52           7             0           CACTGT
# 84 52           7             0           CACTGT
# 85 52           7             0           CACTGT
# 86 52           7             0           CACTGT
# 87 80           7             0           CGTGAT
# 88 80           7             0           CGTGAT
# 89 80           7             0           CGTGAT
# 90 80           7             0           CGTGAT
# 91 80           7             0           CACTGT
# 92 80           7             0           CACTGT
# 93 80           7             0           CACTGT
# 94 80           7             0           CACTGT
# 95 80           7             0           CACTGT
# 96 80           7             0           ATTGGC

# %%
raw_counts <- read_csv(raw_count_file, show_col_types = FALSE)
linked_counts <- read_csv(linked_count_file, show_col_types = FALSE)

# %%
raw_stats <- raw_counts %>%
  filter(umi_count >= umi_cutoff) %>%
  summarize(
    total_barcodes = dplyr::n(), 
    total_umi_count = sum(umi_count), 
    total_read_count = sum(read_count)) %>%
    pivot_longer(everything())

# %% [markdown]
# ### Load insert annotations

# %%
insert_annotations <- read_csv("../../20221229_exp182_rbp_dual_sgrna_linkage/annotations/insert_annotations/rbp_dual_sgrna_linkage.csv", show_col_types = F) %>%
  mutate(sgrna = str_c(sgrna1_name, str_extract(sgrna2_name, "..$"))) %>%
  select(insert_num, gene_name, sgrna)

insert_annotations
# Out:
#      insert_num gene_name  sgrna
# 1     0         A1CF       A1CF_1_2
# 2     1         A1CF       A1CF_2_3
# 3     2         A1CF       A1CF_3_4
# 4     3         A1CF       A1CF_4_1
# 5     4         AAR2       AAR2_1_2
# 6     5         AAR2       AAR2_2_3
# 7     6         AAR2       AAR2_3_4
# 8     7         AAR2       AAR2_4_1
# 9     8         AARS1      AARS1_1_2
# 10    9         AARS1      AARS1_2_3
# 11   10         AARS1      AARS1_3_4
# 12   11         AARS1      AARS1_4_1
# 13   12         AARS2      AARS2_1_2
# 14   13         AARS2      AARS2_2_3
# 15   14         AARS2      AARS2_3_4
# 16   15         AARS2      AARS2_4_1
# 17   16         AARSD1     AARSD1_1_2
# 18   17         AARSD1     AARSD1_2_3
# 19   18         AARSD1     AARSD1_3_4
# 20   19         AARSD1     AARSD1_4_1
# 21   20         AATF       AATF_1_2
# 22   21         AATF       AATF_2_3
# 23   22         AATF       AATF_3_4
# 24   23         AATF       AATF_4_1
# 25   24         ABCE1      ABCE1_1_2
# 26   25         ABCE1      ABCE1_2_3
# 27   26         ABCE1      ABCE1_3_4
# 28   27         ABCE1      ABCE1_4_1
# 29   28         ABCF1      ABCF1_1_2
# 30   29         ABCF1      ABCF1_2_3
# ⋮    ⋮          ⋮          ⋮
# 8731 8730       FLUC       FLUC_3_4
# 8732 8731       FLUC       FLUC_4_1
# 8733 8732       MCHERRY    MCHERRY_1_2
# 8734 8733       MCHERRY    MCHERRY_2_3
# 8735 8734       MCHERRY    MCHERRY_3_4
# 8736 8735       MCHERRY    MCHERRY_4_1
# 8737 8736       NLUC       NLUC_1_2
# 8738 8737       NLUC       NLUC_2_3
# 8739 8738       NLUC       NLUC_3_4
# 8740 8739       NLUC       NLUC_4_1
# 8741 8740       PURO       PURO_1_2
# 8742 8741       PURO       PURO_2_3
# 8743 8742       PURO       PURO_3_4
# 8744 8743       PURO       PURO_4_1
# 8745 8744       MNEONGREEN MNEONGREEN_1_2
# 8746 8745       MNEONGREEN MNEONGREEN_2_3
# 8747 8746       MNEONGREEN MNEONGREEN_3_4
# 8748 8747       MNEONGREEN MNEONGREEN_4_1
# 8749 8748       ZSGREEN1   ZSGREEN1_1_2
# 8750 8749       ZSGREEN1   ZSGREEN1_2_3
# 8751 8750       ZSGREEN1   ZSGREEN1_3_4
# 8752 8751       ZSGREEN1   ZSGREEN1_4_1
# 8753 8752       MTAGBFP2   MTAGBFP2_1_2
# 8754 8753       MTAGBFP2   MTAGBFP2_2_3
# 8755 8754       MTAGBFP2   MTAGBFP2_3_4
# 8756 8755       MTAGBFP2   MTAGBFP2_4_1
# 8757 8756       HYGRO      HYGRO_1_2
# 8758 8757       HYGRO      HYGRO_2_3
# 8759 8758       HYGRO      HYGRO_3_4
# 8760 8759       HYGRO      HYGRO_4_1

# %%
linked_stats <- linked_counts %>%
  filter(umi_count >= umi_cutoff) %>%
  left_join(insert_annotations, by = "insert_num") %>%
  group_by(insert_num) %>%
  summarize(n_barcodes = dplyr::n(), umi_count = sum(umi_count), read_count = sum(read_count), gene_name = first(gene_name), .groups = "drop") %>%
  summarize(
    total_genes = dplyr::n_distinct(gene_name),
    total_inserts = dplyr::n(),
    total_linked_read_count = sum(read_count), 
    total_linked_umi_count = sum(umi_count), 
    total_linked_barcodes = sum(n_barcodes),
    median_barcodes_per_insert = median(n_barcodes), 
    median_reads_per_insert = median(read_count), 
    median_umis_per_insert = median(umi_count)
  ) %>%
  pivot_longer(everything())

# %%
anti_join(insert_annotations, linked_counts %>%filter(umi_count >= umi_cutoff)) %>%
  group_by(gene_name) %>%
  count() %>%
  arrange(desc(n))
# Out:
# Joining, by = "insert_num"
#    gene_name n
# 1  RPL14     3
# 2  DDX28     2
# 3  RPS5      2
# 4  ZCCHC4    2
# 5  ACAA2     1
# 6  ACO2      1
# 7  ALKBH8    1
# 8  APOBEC3A  1
# 9  ARF1      1
# 10 ARHGEF1   1
# 11 BST2      1
# 12 CCT8      1
# 13 CFL1      1
# 14 CRYZ      1
# 15 DAZ4      1
# 16 DHX35     1
# 17 DHX8      1
# 18 EIF3A     1
# 19 EIF4A3    1
# 20 EIF4E     1
# 21 ENOX1     1
# 22 EXOSC5    1
# 23 FAM133B   1
# 24 FASTK     1
# 25 FLNB      1
# 26 G3BP2     1
# 27 GATC      1
# 28 GRN       1
# 29 HABP4     1
# 30 HAP1      1
# ⋮  ⋮         ⋮
# 50 PNRC2     1
# 51 POLDIP3   1
# 52 POLR2J2   1
# 53 POLR2L    1
# 54 PPARGC1B  1
# 55 PRMT1     1
# 56 PUS7      1
# 57 R3HCC1L   1
# 58 RAC1      1
# 59 RANBP6    1
# 60 RBM26     1
# 61 RBM5      1
# 62 RBMXL3    1
# 63 RPL27A    1
# 64 RPS16     1
# 65 RPS28     1
# 66 RPS3A     1
# 67 RRP15     1
# 68 SERPINH1  1
# 69 SF3B3     1
# 70 SFN       1
# 71 SMG5      1
# 72 SSBP1     1
# 73 STX18     1
# 74 SUCO      1
# 75 UBA1      1
# 76 UTP25     1
# 77 XIRP1     1
# 78 YLPM1     1
# 79 ZCCHC13   1

# %%
8676/8760*100
# Out:
# [1] 99.0411

# %%
bind_rows(raw_stats, linked_stats) %>%
  write_csv(output_file)
# Out:
#    name                       value
# 1  total_barcodes               219606.0
# 2  total_umi_count            51620163.0
# 3  total_read_count           68392283.0
# 4  total_genes                    2186.0
# 5  total_inserts                  8676.0
# 6  total_linked_read_count    26795393.0
# 7  total_linked_umi_count     20543294.0
# 8  total_linked_barcodes         76004.0
# 9  median_barcodes_per_insert        8.0
# 10 median_reads_per_insert        2533.0
# 11 median_umis_per_insert         1953.5
